# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'

query_url = f"{url}appid={api_key}&units={units}&q="

# %%
temperatures = []
locations = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxTemp = []
windSpeed = []
data = [locations, cloudiness, country, date, humidity, lat, lng, maxTemp, windSpeed]
for i in range(len(cities)):
    time.sleep(.2)
    try:
        response = requests.get(query_url + cities[i]).json()
        print("Processing Record " + str(i) + " | " + cities[i] + " " + str(response['main']['temp']))
        temperatures.append(response['main']['temp'])
        locations.append(cities[i])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        windSpeed.append(response['wind']['speed'])
    
    except KeyError:
        print('City not found. Proceed...')
# Out:
# Processing Record 0 | busselton 52.95
# City not found. Proceed...
# Processing Record 2 | ushuaia 34.81
# Processing Record 3 | puerto ayora 77.95
# Processing Record 4 | bredasdorp 71.49
# City not found. Proceed...
# Processing Record 6 | georgetown 82.4
# Processing Record 7 | rikitea 71.33
# Processing Record 8 | san quintin 79.25
# Processing Record 9 | hilo 65.34
# Processing Record 10 | vanimo 82.85
# City not found. Proceed...
# Processing Record 12 | nikolskoye 52.57
# Processing Record 13 | kushima 64.76
# Processing Record 14 | dhidhdhoo 85.73
# Processing Record 15 | culpeper 63
# Processing Record 16 | erenhot 53.51
# Processing Record 17 | punta arenas 36.68
# Processing Record 18 | delta del tigre 62.56
# City not found. Proceed...
# Processing Record 20 | saskylakh 7.61
# Processing Record 21 | mataura 52
# Processing Record 22 | albany 43.23
# Processing Record 23 | airai 75.47
# Processing Record 24 | san patricio 74.39
# Processing Record 25 | atuona 81.95
# Processing Record 26 | thompson 32
# Processing Record 27 | chilca 55.4
# Processing Record 28 | hermanus 67.24
# Processing Record 29 | san pedro de macoris 79.56
# Processing Record 30 | luderitz 75.2
# Processing Record 31 | tuktoyaktuk 15.8
# Processing Record 32 | beloha 72.95
# Processing Record 33 | yar-sale 10.85
# Processing Record 34 | bluff 66.29
# Processing Record 35 | qaanaaq 34.07
# Processing Record 36 | ust-nera 6.53
# Processing Record 37 | carnarvon 77.45
# Processing Record 38 | calabozo 92.57
# Processing Record 39 | maragogi 88.61
# Processing Record 40 | hami 69.71
# Processing Record 41 | bethel 39.76
# Processing Record 42 | ligayan 84.29
# Processing Record 43 | hasaki 57.09
# Processing Record 44 | beringovskiy 31.37
# City not found. Proceed...
# Processing Record 46 | port elizabeth 59.61
# Processing Record 47 | ilorin 101.57
# City not found. Proceed...
# Processing Record 49 | nyurba 30.65
# Processing Record 50 | castro 46.4
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 53 | saldanha 75.83
# Processing Record 54 | alugan 77.09
# Processing Record 55 | waddan 82.67
# Processing Record 56 | jamestown 60.17
# Processing Record 57 | srednekolymsk 20.03
# Processing Record 58 | kavieng 82.85
# City not found. Proceed...
# Processing Record 60 | pitimbu 86
# Processing Record 61 | goderich 40.33
# Processing Record 62 | hobart 52.2
# Processing Record 63 | lamar 41.4
# Processing Record 64 | kuito 78.8
# Processing Record 65 | saint george 76.05
# Processing Record 66 | hazebrouck 54.18
# Processing Record 67 | treinta y tres 62.87
# Processing Record 68 | cidreira 74.39
# Processing Record 69 | lubao 84.52
# Processing Record 70 | dalbandin 80.87
# Processing Record 71 | kruisfontein 61.61
# Processing Record 72 | alice springs 62.6
# City not found. Proceed...
# Processing Record 74 | najran 100.4
# Processing Record 75 | bathsheba 77
# Processing Record 76 | saint-joseph 63.79
# Processing Record 77 | kulhudhuffushi 85.73
# Processing Record 78 | namibe 75.2
# Processing Record 79 | trofors 43.61
# Processing Record 80 | praia 78.19
# Processing Record 81 | pala 87.8
# City not found. Proceed...
# Processing Record 83 | cherskiy 25.25
# Processing Record 84 | miandrivazo 80.69
# City not found. Proceed...
# Processing Record 86 | preobrazheniye 39.83
# Processing Record 87 | victor harbor 56.34
# Processing Record 88 | contai 85.37
# Processing Record 89 | havoysund 33.8
# Processing Record 90 | vaini 81.23
# Processing Record 91 | cape town 65.88
# Processing Record 92 | new norfolk 52.21
# Processing Record 93 | dunedin 55
# Processing Record 94 | necochea 61
# Processing Record 95 | victoria 83.14
# Processing Record 96 | livingstonia 64.13
# Processing Record 97 | high level 12.2
# Processing Record 98 | hobyo 84.65
# Processing Record 99 | santa cruz 52.99
# City not found. Proceed...
# Processing Record 101 | rocha 61.25
# Processing Record 102 | kabalo 85.19
# Processing Record 103 | yellowknife -0.3
# Processing Record 104 | genhe 26.69
# Processing Record 105 | bitkine 102.83
# Processing Record 106 | east london 93.2
# Processing Record 107 | hamilton 72.77
# Processing Record 108 | aykhal 28.4
# City not found. Proceed...
# Processing Record 110 | san juan 52.25
# Processing Record 111 | dikson 9.23
# Processing Record 112 | avera 70.77
# Processing Record 113 | cockburn town 79.61
# City not found. Proceed...
# Processing Record 115 | santa fe 64.02
# Processing Record 116 | bud 52.99
# Processing Record 117 | ossora 29.75
# Processing Record 118 | hofn 50
# Processing Record 119 | badajoz 84.09
# Processing Record 120 | terney 38.75
# Processing Record 121 | mount isa 73.4
# Processing Record 122 | khotyn 64.17
# Processing Record 123 | lexington 66.6
# Processing Record 124 | faya 85.14
# Processing Record 125 | laguna 60.8
# Processing Record 126 | nouadhibou 71.6
# Processing Record 127 | norman wells 21.2
# Processing Record 128 | svetlogorsk 37.4
# Processing Record 129 | vaitape 81.95
# Processing Record 130 | narsaq 46.4
# Processing Record 131 | kurumkan 31.73
# Processing Record 132 | hoi an 78.8
# Processing Record 133 | katsuura 59.07
# City not found. Proceed...
# Processing Record 135 | salalah 89.6
# Processing Record 136 | port lincoln 60.35
# Processing Record 137 | lagoa 69.69
# Processing Record 138 | lebu 77
# Processing Record 139 | lazaro cardenas 65.98
# City not found. Proceed...
# Processing Record 141 | koumac 75.83
# City not found. Proceed...
# Processing Record 143 | butaritari 82.85
# Processing Record 144 | barrow 59.09
# Processing Record 145 | price 38.57
# Processing Record 146 | antofagasta 64.4
# Processing Record 147 | saint-philippe 45
# Processing Record 148 | avarua 78.8
# Processing Record 149 | port alfred 66.99
# Processing Record 150 | torbay 34.88
# Processing Record 151 | iqaluit 28.2
# Processing Record 152 | kapaa 70.05
# City not found. Proceed...
# Processing Record 154 | pisco 71.29
# Processing Record 155 | shetpe 60.89
# Processing Record 156 | khatanga 5.45
# Processing Record 157 | omsukchan 10.85
# Processing Record 158 | ondjiva 93.2
# Processing Record 159 | sept-iles 29.19
# Processing Record 160 | gra liyia 70.14
# Processing Record 161 | bonthe 86.45
# Processing Record 162 | faanui 81.95
# Processing Record 163 | dagana 98.15
# Processing Record 164 | tazovskiy 3.83
# Processing Record 165 | sainte-martine 44.73
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 168 | chokurdakh 5.99
# City not found. Proceed...
# Processing Record 170 | mahebourg 76.73
# Processing Record 171 | shiyan 55
# Processing Record 172 | okhotsk 33.35
# Processing Record 173 | tutoia 84.2
# Processing Record 174 | bambanglipuro 82.49
# Processing Record 175 | zhanaozen 62.69
# Processing Record 176 | warrnambool 64
# Processing Record 177 | navahrudak 59.45
# Processing Record 178 | sur 89.33
# Processing Record 179 | tasiilaq 41
# Processing Record 180 | baruun-urt 48.47
# Processing Record 181 | ayagoz 56.03
# Processing Record 182 | marawi 82
# Processing Record 183 | mmathubudukwane 78.8
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 186 | mar del plata 51.17
# Processing Record 187 | moron 95.27
# Processing Record 188 | sioux lookout 32
# Processing Record 189 | mahbubabad 99.41
# Processing Record 190 | ryuo 60.46
# Processing Record 191 | kaitangata 54
# Processing Record 192 | ancud 46.4
# Processing Record 193 | jiujiang 63.23
# Processing Record 194 | solnechnyy 47.21
# Processing Record 195 | pisek 35.56
# Processing Record 196 | eureka 41.88
# Processing Record 197 | sambava 70.43
# Processing Record 198 | kenora 31.32
# Processing Record 199 | red wing 41.23
# Processing Record 200 | port hardy 32
# Processing Record 201 | ambanja 89.6
# City not found. Proceed...
# Processing Record 203 | nortelandia 84.29
# Processing Record 204 | oga 97.07
# Processing Record 205 | ust-ordynskiy 51.8
# Processing Record 206 | mumbwa 74.75
# Processing Record 207 | bambous virieux 76.8
# Processing Record 208 | tiksi 5.81
# Processing Record 209 | gushikawa 78.6
# Processing Record 210 | husavik 36
# Processing Record 211 | paamiut 40.19
# Processing Record 212 | poum 53.6
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 215 | fallon 26.6
# Processing Record 216 | margate 52.21
# Processing Record 217 | sipoo 53.46
# Processing Record 218 | zhuhai 53.6
# City not found. Proceed...
# Processing Record 220 | agadir 75.2
# Processing Record 221 | coquimbo 66.2
# Processing Record 222 | berlevag 32.45
# Processing Record 223 | yulara 62.6
# Processing Record 224 | arraial do cabo 78.8
# Processing Record 225 | seoul 56.44
# Processing Record 226 | lompoc 54.3
# Processing Record 227 | balkhash 64.67
# Processing Record 228 | sao felix do xingu 80.51
# Processing Record 229 | iki-burul 46.4
# Processing Record 230 | alofi 73.4
# Processing Record 231 | hithadhoo 84.29
# Processing Record 232 | pokhara 57.29
# Processing Record 233 | champerico 73.4
# Processing Record 234 | buala 82.85
# Processing Record 235 | chuy 62.69
# Processing Record 236 | kentau 62.33
# Processing Record 237 | sorong 77.27
# City not found. Proceed...
# Processing Record 239 | remerschen 62.76
# Processing Record 240 | sokoto 105.71
# Processing Record 241 | juneau 32.38
# Processing Record 242 | zonguldak 73.13
# Processing Record 243 | hambantota 78.8
# Processing Record 244 | hualmay 65.57
# Processing Record 245 | mezen 35.69
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 248 | saint anthony 27.61
# Processing Record 249 | muzhi 21.83
# Processing Record 250 | vardo 60.64
# Processing Record 251 | sitka 45
# Processing Record 252 | vila franca do campo 57.7
# City not found. Proceed...
# Processing Record 254 | antsohihy 82.31
# Processing Record 255 | esperance 86
# City not found. Proceed...
# Processing Record 257 | ketchikan 44.76
# Processing Record 258 | lakewood 57.43
# Processing Record 259 | staryy nadym 9.05
# Processing Record 260 | provideniya 32.27
# Processing Record 261 | naron 58.87
# Processing Record 262 | olinda 80.2
# Processing Record 263 | magalia 50.79
# Processing Record 264 | montemor-o-novo 79.43
# Processing Record 265 | port-gentil 86
# Processing Record 266 | hay river 5
# Processing Record 267 | monheim 55.08
# Processing Record 268 | gat 84.2
# Processing Record 269 | baglung 57.29
# Processing Record 270 | saint-leu 73.51
# Processing Record 271 | juan aldama 64.4
# Processing Record 272 | nkpor 93.83
# Processing Record 273 | nanortalik 39.65
# Processing Record 274 | fortuna 69.42
# City not found. Proceed...
# Processing Record 276 | clyde river 19.4
# Processing Record 277 | pandan niog 83.93
# Processing Record 278 | nalut 82.13
# Processing Record 279 | kahului 66.81
# Processing Record 280 | san andres 78.89
# Processing Record 281 | san cristobal 54.18
# Processing Record 282 | sao jose da coroa grande 88.61
# Processing Record 283 | matagami 97.97
# City not found. Proceed...
# Processing Record 285 | krasnopavlivka 50.09
# Processing Record 286 | longyearbyen 19.4
# Processing Record 287 | bang saphan 81.77
# Processing Record 288 | lasa 76.75
# Processing Record 289 | karnobat 74.88
# Processing Record 290 | abrau-dyurso 71.2
# Processing Record 291 | saint-louis 55.81
# Processing Record 292 | yerbogachen 40.55
# Processing Record 293 | taoudenni 104.45
# Processing Record 294 | ovruch 57.29
# Processing Record 295 | guerrero negro 60.17
# Processing Record 296 | hue 82.4
# Processing Record 297 | huarmey 66.47
# Processing Record 298 | kavaratti 86.09
# City not found. Proceed...
# Processing Record 300 | axim 84.83
# Processing Record 301 | grindavik 56.05
# Processing Record 302 | omboue 81.23
# Processing Record 303 | amapa 80.85
# Processing Record 304 | chintamani 86.49
# Processing Record 305 | yagodnoye 15.35
# City not found. Proceed...
# Processing Record 307 | marshall 56.62
# Processing Record 308 | quatre cocos 76.95
# Processing Record 309 | saint-ambroise 66.36
# City not found. Proceed...
# Processing Record 311 | sharkan 39.99
# Processing Record 312 | edwardsville 58.66
# Processing Record 313 | colares 68.25
# Processing Record 314 | constitucion 57.06
# Processing Record 315 | karaton 81.68
# City not found. Proceed...
# Processing Record 317 | baykit 24.53
# Processing Record 318 | sheboygan 39
# City not found. Proceed...
# Processing Record 320 | tura 81.05
# Processing Record 321 | lorengau 78.17
# City not found. Proceed...
# Processing Record 323 | homer 41.83
# Processing Record 324 | roma 61.75
# Processing Record 325 | mae tha 94.06
# Processing Record 326 | klaksvik 48.2
# Processing Record 327 | vestmannaeyjar 48.2
# Processing Record 328 | ilulissat 46.4
# Processing Record 329 | carolina 81.19
# Processing Record 330 | alice town 77.99
# City not found. Proceed...
# Processing Record 332 | aksu 39.2
# Processing Record 333 | charters towers 67.73
# Processing Record 334 | ambon 63.73
# Processing Record 335 | severo-kurilsk 35.69
# Processing Record 336 | ariquemes 81.95
# Processing Record 337 | longview 73.89
# Processing Record 338 | ostrovnoy 36.41
# Processing Record 339 | sandwick 60.58
# Processing Record 340 | andilamena 63.77
# Processing Record 341 | nuuk 35.33
# Processing Record 342 | cabo san lucas 67.26
# Processing Record 343 | biak 64.13
# Processing Record 344 | boguchany 50.45
# Processing Record 345 | alta floresta 82.4
# Processing Record 346 | jinchang 50.99
# Processing Record 347 | churapcha 24.71
# Processing Record 348 | nishihara 58.37
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 351 | hailey 30.65
# City not found. Proceed...
# Processing Record 353 | bekhtery 71.6
# Processing Record 354 | egvekinot 32.99
# Processing Record 355 | boca do acre 89.69
# Processing Record 356 | merk 58.8
# Processing Record 357 | sebeta 77
# Processing Record 358 | shahreza 63.77
# Processing Record 359 | chifeng 49.01
# Processing Record 360 | mattru 86.09
# Processing Record 361 | suleja 91.4
# Processing Record 362 | atasu 36.77
# Processing Record 363 | kloulklubed 78.8
# Processing Record 364 | port hedland 75.2
# Processing Record 365 | barabinsk 32.99
# Processing Record 366 | atambua 82.49
# Processing Record 367 | fereydun kenar 66.2
# Processing Record 368 | tabou 83.93
# Processing Record 369 | luang prabang 91.4
# City not found. Proceed...
# Processing Record 371 | kodiak 48.51
# Processing Record 372 | uray 31.91
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 375 | iquitos 78.8
# Processing Record 376 | comodoro rivadavia 50
# Processing Record 377 | corum 72.93
# Processing Record 378 | labuhan 75.47
# Processing Record 379 | mogadishu 89.6
# Processing Record 380 | nurota 77
# Processing Record 381 | tuatapere 52
# Processing Record 382 | oktyabrskiy 55.4
# Processing Record 383 | puerto madryn 55.49
# Processing Record 384 | vao 52.61
# Processing Record 385 | pacific grove 53.51
# City not found. Proceed...
# Processing Record 387 | sovetskaya gavan 47.03
# Processing Record 388 | udachnyy 28.4
# Processing Record 389 | ponta do sol 78.71
# Processing Record 390 | pinillos 92.03
# City not found. Proceed...
# Processing Record 392 | muroto 61.25
# Processing Record 393 | cap malheureux 77.18
# Processing Record 394 | waipawa 46
# Processing Record 395 | beyneu 56.75
# Processing Record 396 | warangal 95.81
# Processing Record 397 | mae sot 78.89
# Processing Record 398 | elliot lake 39.2
# Processing Record 399 | upernavik 37.13
# Processing Record 400 | kampot 84.2
# Processing Record 401 | lage 62.29
# Processing Record 402 | payo 72.95
# Processing Record 403 | inirida 93.65
# Processing Record 404 | vilyuysk 27.77
# Processing Record 405 | lata 28.31
# Processing Record 406 | alabaster 69.67
# Processing Record 407 | saint-francois 64.78
# Processing Record 408 | khasan 45.77
# City not found. Proceed...
# Processing Record 410 | burns lake 34.61
# Processing Record 411 | gasa 31.37
# Processing Record 412 | salina 70.56
# Processing Record 413 | la ronge 30.2
# Processing Record 414 | evensk 29.21
# Processing Record 415 | aklavik 25.14
# Processing Record 416 | seymchan 19.31
# Processing Record 417 | hermiston 38.59
# Processing Record 418 | porto novo 69.8
# Processing Record 419 | paracuru 77
# Processing Record 420 | boende 77.09
# Processing Record 421 | nadapuram 86
# Processing Record 422 | petropavlovsk-kamchatskiy 33.8
# Processing Record 423 | vilhena 77
# City not found. Proceed...
# Processing Record 425 | mezhdurechensk 52.43
# Processing Record 426 | karasjok 41
# Processing Record 427 | ribeira grande 66.2
# Processing Record 428 | bani 81.59
# Processing Record 429 | nadvoitsy 51.89
# Processing Record 430 | raudeberg 58.42
# Processing Record 431 | sao filipe 72.41
# Processing Record 432 | bosaso 86
# Processing Record 433 | tual 82.31
# Processing Record 434 | kaohsiung 80.37
# City not found. Proceed...
# Processing Record 436 | mahanoro 68.99
# Processing Record 437 | iranshahr 95
# Processing Record 438 | copiapo 57.2
# Processing Record 439 | abu dhabi 90.79
# City not found. Proceed...
# Processing Record 441 | hammerfest 36.86
# City not found. Proceed...
# Processing Record 443 | bataipora 81.23
# Processing Record 444 | severnyy-kospashskiy 30.99
# Processing Record 445 | satara 80.69
# City not found. Proceed...
# City not found. Proceed...
# Processing Record 448 | kualakapuas 80.6
# Processing Record 449 | vangaindrano 69.17
# Processing Record 450 | ixtapa 68.83
# Processing Record 451 | yerkoy 72.77
# Processing Record 452 | lakselv 39.22
# Processing Record 453 | gizo 75.25
# Processing Record 454 | iralaya 87.17
# Processing Record 455 | bongandanga 77.45
# Processing Record 456 | marsh harbour 75.65
# Processing Record 457 | casper 27.32
# Processing Record 458 | dukat 60.01
# City not found. Proceed...
# Processing Record 460 | puerto escondido 78.8
# Processing Record 461 | codrington 62.92
# Processing Record 462 | uspenka 57.11
# Processing Record 463 | zilair 34.79
# Processing Record 464 | umm kaddadah 104.27
# Processing Record 465 | humaita 65.75
# Processing Record 466 | bredy 37.67
# City not found. Proceed...
# Processing Record 468 | velsk 45.77
# Processing Record 469 | itaituba 82.4
# Processing Record 470 | taree 62.26
# Processing Record 471 | imbituba 73.4
# Processing Record 472 | capitan bado 81.59
# Processing Record 473 | skelleftea 60.8
# City not found. Proceed...
# Processing Record 475 | jiazi 78.8
# Processing Record 476 | ust-ilimsk 46.85
# Processing Record 477 | ulladulla 60.8
# Processing Record 478 | athabasca 25.97
# Processing Record 479 | oistins 77
# Processing Record 480 | maniitsoq 50.27
# Processing Record 481 | fernley 45.99
# Processing Record 482 | tenenkou 108.77
# Processing Record 483 | karatuzskoye 57.83
# Processing Record 484 | meulaboh 84.65
# Processing Record 485 | kuruman 79
# Processing Record 486 | hadishahr 72.34
# Processing Record 487 | shellbrook 28.4
# Processing Record 488 | cabedelo 86
# Processing Record 489 | yining 58.55
# Processing Record 490 | oranjestad 84.2
# City not found. Proceed...
# Processing Record 492 | shimoda 59.14
# Processing Record 493 | westport 53.69
# Processing Record 494 | mount gambier 62.6
# Processing Record 495 | port blair 85.19
# Processing Record 496 | mitu 63.77
# Processing Record 497 | te anau 39.65
# Processing Record 498 | yashkul 52.97
# Processing Record 499 | kitui 73.31
# Processing Record 500 | flinders 64.56
# Processing Record 501 | teabo 87.71
# Processing Record 502 | pangyan 83.21
# Processing Record 503 | gornopravdinsk 21.47
# Processing Record 504 | goma 60.53
# Processing Record 505 | dondo 82.4
# Processing Record 506 | mayo 26.6
# Processing Record 507 | coihaique 42.8
# Processing Record 508 | richmond 43.11
# Processing Record 509 | cangzhou 62.15
# Processing Record 510 | lovington 57.2
# Processing Record 511 | riyadh 93.2
# Processing Record 512 | khorramshahr 95
# Processing Record 513 | marsa matruh 78.8
# Processing Record 514 | new haven 45.1
# Processing Record 515 | vila velha 77
# Processing Record 516 | roebourne 81.59
# Processing Record 517 | souillac 65.77
# Processing Record 518 | beihai 51.87
# City not found. Proceed...
# Processing Record 520 | huejuquilla el alto 73.31
# Processing Record 521 | kargasok 23.81
# Processing Record 522 | komsomolskiy 18.23
# Processing Record 523 | concepcion del uruguay 64
# Processing Record 524 | wonosari 77
# Processing Record 525 | behbahan 91.27
# Processing Record 526 | poplar bluff 71.42
# Processing Record 527 | dingle 77.45
# Processing Record 528 | ishigaki 79.97
# Processing Record 529 | fairbanks 37.99
# Processing Record 530 | kviteseid 71.6
# City not found. Proceed...
# Processing Record 532 | chamonix-mont-blanc 56.37
# Processing Record 533 | truckee 45.52
# Processing Record 534 | aguimes 73.63
# Processing Record 535 | mae ramat 78.89
# Processing Record 536 | nador 71.08
# Processing Record 537 | holsted 61.99
# Processing Record 538 | sohag 102.2
# City not found. Proceed...
# Processing Record 540 | sao joao da barra 81.54
# Processing Record 541 | acapulco 73.4
# Processing Record 542 | fort nelson 28.4
# Processing Record 543 | kokopo 71.87
# Processing Record 544 | soe 56.75
# Processing Record 545 | wagga wagga 64.45
# Processing Record 546 | khandyga 16.79
# City not found. Proceed...
# Processing Record 548 | clarksburg 63.68
# Processing Record 549 | wanning 54.12
# Processing Record 550 | touros 83.57
# City not found. Proceed...
# Processing Record 552 | dudinka 6.8
# City not found. Proceed...
# Processing Record 554 | ashqelon 74.98
# Processing Record 555 | khash 69.17
# Processing Record 556 | atar 103.01
# Processing Record 557 | villablino 71.71
# Processing Record 558 | naze 89.6
# Processing Record 559 | nabire 70.97
# Processing Record 560 | inongo 88.61
# Processing Record 561 | chubbuck 28.4
# Processing Record 562 | binga 77.99
# Processing Record 563 | lavrentiya 25.79
# Processing Record 564 | sfantu gheorghe 59.41
# Processing Record 565 | dubovka 39.2
# Processing Record 566 | san policarpo 81.05
# City not found. Proceed...
# Processing Record 568 | bereda 63.45
# Processing Record 569 | san carlos de bariloche 39.2
# Processing Record 570 | creston 46.83
# Processing Record 571 | nikitinskiy 71.17
# Processing Record 572 | half moon bay 53.11
# Processing Record 573 | coracora 58.73
# Processing Record 574 | beyla 84
# Processing Record 575 | san angelo 68.88
# Processing Record 576 | dongtai 63.99
# Processing Record 577 | luwingu 71.87
# Processing Record 578 | rio gallegos 35.6
# Processing Record 579 | aswan 100.31
# Processing Record 580 | rudnichnyy 31.55
# Processing Record 581 | havre-saint-pierre 26.6
# Processing Record 582 | bombay 44.6
# Processing Record 583 | manggar 78.53
# Processing Record 584 | bara 105.35
# Processing Record 585 | kinna 65.77
# Processing Record 586 | comarapa 76.01
# City not found. Proceed...
# Processing Record 588 | shingu 55.31
# Processing Record 589 | prince rupert 37.4
# Processing Record 590 | farah 78.71
# Processing Record 591 | chumikan 31.55
# Processing Record 592 | rumonge 73.49
# Processing Record 593 | rabak 109.13
# Processing Record 594 | clarence town 63.68
# Processing Record 595 | ganzhou 62.69
# Processing Record 596 | jeremie 84.65
# Processing Record 597 | challans 65.07
# Processing Record 598 | bonoua 84.2
# Processing Record 599 | noshiro 50.09
# Processing Record 600 | noumea 66.2
# Processing Record 601 | labuan 82.24
# Processing Record 602 | ljungby 61.05
# Processing Record 603 | abonnema 89.6

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citiesWeather_df = pd.DataFrame()
columns = ['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']
for i in range(len(columns)):
    citiesWeather_df[columns[i]] = data[i]
    
citiesWeather_df.count()
# Out:
# City          535
# Cloudiness    535
# Country       535
# Date          535
# Humidity      535
# Lat           535
# Lng           535
# Max Temp      535
# Wind Speed    535
# dtype: int64

# %%
citiesWeather_df.to_csv('data/cities_weather_data.csv', index = False)
citiesWeather_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-3b339336607d> in <module>
# ----> 1 citiesWeather_df.to_csv('data/cities_weather_data.csv', index = False)
#       2 citiesWeather_df
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cities_weather_data.csv'
